# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### A)

# %%
Aleatorio = np.array(range(-5,6))
Aleatorio = np.random.choice(Aleatorio, 10)
Aleatorio
# Out:
# array([ 4, -5, -2, -1, -4, -3, -3, -4,  2, -5])

# %% [markdown]
# #### B)

# %%
Graf = plt.plot(Aleatorio)
plt.xlabel("X")
plt.ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')
